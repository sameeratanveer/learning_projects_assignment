# %%
# Import all the necessary libraries : 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load the data : 
df = pd.read_csv('Salary Data.csv')

# %% [markdown]
# # ---------------------------------- FE --------------------------------

# %% [markdown]
# ### 1_ Handling Duplicates

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (325, 6)

# %% [markdown]
# ### 2_ Missing Value Handling - Only one missing values (Better to drop it)

# %%
df.isnull().sum()
# Out:
# Age                    1
# Gender                 1
# Education Level        1
# Job Title              1
# Years of Experience    1
# Salary                 1
# dtype: int64

# %% [markdown]
# #### Dropped Null value 1 row

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (324, 6)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %% [markdown]
# #### 3_ Encoding (Categorical to Numerical) - Gender, Education Level, Job Title

# %% [markdown]
# #### 1_ Gender Encoding :

# %%
#Using One Hot Encoding : 
df = pd.get_dummies(df, columns=['Gender'], drop_first=True)

# %%
df["Gender_Male"] = df["Gender_Male"].astype(int)

# %%
df
# Out:
#       Age Education Level                            Job Title  \
# 0    32.0      Bachelor's                    Software Engineer
# 1    28.0        Master's                         Data Analyst
# 2    45.0             PhD                       Senior Manager
# 3    36.0      Bachelor's                      Sales Associate
# 4    52.0        Master's                             Director
# ..    ...             ...                                  ...
# 348  28.0      Bachelor's            Junior Operations Manager
# 349  36.0      Bachelor's  Senior Business Development Manager
# 350  44.0             PhD                Senior Data Scientist
# 351  31.0      Bachelor's         Junior Marketing Coordinator
# 371  43.0        Master's               Director of Operations
#
#      Years of Experience    Salary  Gender_Male
# 0                    5.0   90000.0            1
# 1                    3.0   65000.0            0
# 2                   15.0  150000.0            1
# 3                    7.0   60000.0            0
# 4                   20.0  200000.0            1
# ..                   ...       ...          ...
# 348                  1.0   35000.0            0
# 349                  8.0  110000.0            1
# 350                 16.0  160000.0            0
# 351                  3.0   55000.0            1
# 371                 19.0  170000.0            1
#
# [324 rows x 6 columns]

# %% [markdown]
# #### 2_ Education Level Encoding :

# %%
# Using Ordinal Encoding : 
from sklearn.preprocessing import OrdinalEncoder
categories = [["PhD", "Master's", "Bachelor's"]]
encoder = OrdinalEncoder(categories=categories)
df['edu_ord'] = encoder.fit_transform(df[['Education Level']]).astype(int)

# %%
df
# Out:
#       Age Education Level                            Job Title  \
# 0    32.0      Bachelor's                    Software Engineer
# 1    28.0        Master's                         Data Analyst
# 2    45.0             PhD                       Senior Manager
# 3    36.0      Bachelor's                      Sales Associate
# 4    52.0        Master's                             Director
# ..    ...             ...                                  ...
# 348  28.0      Bachelor's            Junior Operations Manager
# 349  36.0      Bachelor's  Senior Business Development Manager
# 350  44.0             PhD                Senior Data Scientist
# 351  31.0      Bachelor's         Junior Marketing Coordinator
# 371  43.0        Master's               Director of Operations
#
#      Years of Experience    Salary  Gender_Male  edu_ord
# 0                    5.0   90000.0            1        2
# 1                    3.0   65000.0            0        1
# 2                   15.0  150000.0            1        0
# 3                    7.0   60000.0            0        2
# 4                   20.0  200000.0            1        1
# ..                   ...       ...          ...      ...
# 348                  1.0   35000.0            0        2
# 349                  8.0  110000.0            1        2
# 350                 16.0  160000.0            0        0
# 351                  3.0   55000.0            1        2
# 371                 19.0  170000.0            1        1
#
# [324 rows x 7 columns]

# %% [markdown]
# #### 3_  Job Title Encoding : Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['job_title'] = encoder.fit_transform(df['Job Title'])

# %%
df
# Out:
#       Age Education Level                            Job Title  \
# 0    32.0      Bachelor's                    Software Engineer
# 1    28.0        Master's                         Data Analyst
# 2    45.0             PhD                       Senior Manager
# 3    36.0      Bachelor's                      Sales Associate
# 4    52.0        Master's                             Director
# ..    ...             ...                                  ...
# 348  28.0      Bachelor's            Junior Operations Manager
# 349  36.0      Bachelor's  Senior Business Development Manager
# 350  44.0             PhD                Senior Data Scientist
# 351  31.0      Bachelor's         Junior Marketing Coordinator
# 371  43.0        Master's               Director of Operations
#
#      Years of Experience    Salary  Gender_Male  edu_ord  job_title
# 0                    5.0   90000.0            1        2        159
# 1                    3.0   65000.0            0        1         17
# 2                   15.0  150000.0            1        0        130
# 3                    7.0   60000.0            0        2        101
# 4                   20.0  200000.0            1        1         22
# ..                   ...       ...          ...      ...        ...
# 348                  1.0   35000.0            0        2         68
# 349                  8.0  110000.0            1        2        111
# 350                 16.0  160000.0            0        0        115
# 351                  3.0   55000.0            1        2         63
# 371                 19.0  170000.0            1        1         30
#
# [324 rows x 8 columns]

# %%
df = df.drop(columns=['Education Level', 'Job Title'], axis=1)

# %%
df
# Out:
#       Age  Years of Experience    Salary  Gender_Male  edu_ord  job_title
# 0    32.0                  5.0   90000.0            1        2        159
# 1    28.0                  3.0   65000.0            0        1         17
# 2    45.0                 15.0  150000.0            1        0        130
# 3    36.0                  7.0   60000.0            0        2        101
# 4    52.0                 20.0  200000.0            1        1         22
# ..    ...                  ...       ...          ...      ...        ...
# 348  28.0                  1.0   35000.0            0        2         68
# 349  36.0                  8.0  110000.0            1        2        111
# 350  44.0                 16.0  160000.0            0        0        115
# 351  31.0                  3.0   55000.0            1        2         63
# 371  43.0                 19.0  170000.0            1        1         30
#
# [324 rows x 6 columns]

# %%
df = df[['Age', 'Years of Experience', 'Salary', 'Gender_Male', 'edu_ord', 'job_title']].astype(int)

# %%
df
# Out:
#      Age  Years of Experience  Salary  Gender_Male  edu_ord  job_title
# 0     32                    5   90000            1        2        159
# 1     28                    3   65000            0        1         17
# 2     45                   15  150000            1        0        130
# 3     36                    7   60000            0        2        101
# 4     52                   20  200000            1        1         22
# ..   ...                  ...     ...          ...      ...        ...
# 348   28                    1   35000            0        2         68
# 349   36                    8  110000            1        2        111
# 350   44                   16  160000            0        0        115
# 351   31                    3   55000            1        2         63
# 371   43                   19  170000            1        1         30
#
# [324 rows x 6 columns]

# %%
df.rename(columns={'Age':'age', 'Years of Experience':'years_of_experience','Salary':'salary', 'Gender_Male':'gender_male', 'edu_ord':'education_level'}, inplace=True)

# %%
df
# Out:
#      age  years_of_experience  salary  gender_male  education_level  job_title
# 0     32                    5   90000            1                2        159
# 1     28                    3   65000            0                1         17
# 2     45                   15  150000            1                0        130
# 3     36                    7   60000            0                2        101
# 4     52                   20  200000            1                1         22
# ..   ...                  ...     ...          ...              ...        ...
# 348   28                    1   35000            0                2         68
# 349   36                    8  110000            1                2        111
# 350   44                   16  160000            0                0        115
# 351   31                    3   55000            1                2         63
# 371   43                   19  170000            1                1         30
#
# [324 rows x 6 columns]

# %%
df
# Out:
#      age  years_of_experience  salary  gender_male  education_level  job_title
# 0     32                    5   90000            1                2        159
# 1     28                    3   65000            0                1         17
# 2     45                   15  150000            1                0        130
# 3     36                    7   60000            0                2        101
# 4     52                   20  200000            1                1         22
# ..   ...                  ...     ...          ...              ...        ...
# 348   28                    1   35000            0                2         68
# 349   36                    8  110000            1                2        111
# 350   44                   16  160000            0                0        115
# 351   31                    3   55000            1                2         63
# 371   43                   19  170000            1                1         30
#
# [324 rows x 6 columns]

# %%
from joblib import dump

# %% [markdown]
# # Saving the DataFrame after FE

# %%
dump(df, 'df_fe.joblib')
# Out:
# ['df_fe.joblib']
